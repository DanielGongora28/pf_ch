# %% [markdown]
# ## **Descripcion e inicializacion del proyecto**
#
# La crisis de la vivienda en los Países Bajos es uno de los mayores problemas a los que se enfrentan los residentes. Debido a múltiples factores, como el crecimiento de la población y la escasez de trabajadores de la construcción, la disponibilidad de viviendas ha disminuido significativamente. Medidas como la desgravación fiscal de las hipotecas para los compradores han contribuido a aumentar los precios, al igual que otras supuestamente destinadas a ayudar a los compradores jóvenes, pero que han acabado ayudando a los propietarios existentes a adquirir más propiedades. Esta disminución ha elevado los precios del alquiler a niveles altísimos, lo que ha llevado a muchos a preguntarse si se están aprovechando de ellos.
#
# Para responder a esta inquietud, se proporcionara una solucion analitica para predecir el alquiler de una casa a partir de diferentes caracteristicas analizadas mas adelante.
#
# El análisis de los datos elegidos está motivado por la necesidad de comprender mejor el mercado de alquiler de propiedades, identificar patrones y tendencias, y optimizar tanto la oferta como la demanda en este sector. Este análisis permitirá descubrir oportunidades para mejorar la experiencia de los inquilinos y propietarios, identificar áreas de alto crecimiento, y optimizar los precios de alquiler basados en diversas variables como la ubicación, características del inmueble, y condiciones de convivencia.
#
# Ademas de la busqueda de hacer ver a Europa y los paises bajos como un lugar con estabilidad de vivienda y calidad de vida, evitando titulares como:
#
#
# *   [*La crisis de la vivienda se extiende por toda Europa, pero la de Holanda está ya en otro nivel*](https://www.eldiario.es/internacional/theguardian/crisis-vivienda-extiende-europa-holanda-nivel_1_11345479.html)
#
# *   [*La crisis de la vivienda en Países Bajos: una burbuja sin oxígeno*](https://www.swissinfo.ch/spa/la-crisis-de-la-vivienda-en-países-bajos-una-burbuja-sin-oxígeno/47342426)
#
# * [*Refugiados y crisis de la vivienda, la tormenta perfecta en Países Bajos*](https://es.euronews.com/my-europe/2023/07/27/refugiados-y-crisis-de-la-vivienda-la-tormenta-perfecta-en-paises-bajos)
#
# <br>
#
# La audiencia que se beneficiará de este análisis incluye propietarios y administradores de propiedades, empresas de gestión inmobiliaria, potenciales inquilinos que buscan una propiedad adecuada a sus necesidades, y plataformas de alquiler que desean mejorar la precisión de sus recomendaciones y servicios. Además, inversores en bienes raíces también podrían utilizar este análisis para tomar decisiones informadas sobre dónde y en qué tipo de propiedades invertir.

# %% [markdown]
# ### Preguntas de negocio
#
# ¿Que relacionen existen entre las diferentes variables que influyen en el costo total de una alquiler?
#
# ¿Podemos establecer la influencia de patrones o situaciones externas sobre el precio de las propiedades?
#
# ¿Cuales son las principales caracteristicas que hacen crecer o decrecer el precio de los alquileres?
#
# ¿Existen patrones de sobrecostos relacionados con una caracteristica especifica del lugar a arrendar?

# %% [markdown]
# ## Conexion a la API y carga de datos

# %%
api_token={"username":"danielgongoragarcia","key":"51710779b70f16c389cbaf9c7eeb5b2b"}

# %%
# !rm -rf /root/.kaggle.

# %%
# !mkdir /root/.kaggle

# %%
import json
with open('/root/.kaggle/kaggle.json','w') as file:
    json.dump(api_token,file)

# %%
# !kaggle competitions download -c fcg-2022-netherlands-accommodation-prices
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading fcg-2022-netherlands-accommodation-prices.zip to /content
#  71% 12.0M/16.8M [00:00<00:00, 48.1MB/s]
# 100% 16.8M/16.8M [00:00<00:00, 52.4MB/s]

# %%
import zipfile
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# %%
archivozip='/content/fcg-2022-netherlands-accommodation-prices.zip'

# %%
with zipfile.ZipFile(archivozip,'r') as zip_file:
  for nombre_archivo in zip_file.namelist():
    print(nombre_archivo)
# Out:
# sample_submission.csv
# test.csv
# train.csv

# %%
nombre_archivo='train.csv'
nombre_archivo2='test.csv'
with zipfile.ZipFile(archivozip,'r') as zip_file:
  with zip_file.open(nombre_archivo) as csv:
    df=pd.read_csv(csv)
  with zip_file.open(nombre_archivo2) as csv2:
      df2=pd.read_csv(csv2)

# %% [markdown]
# ## EDA

# %%
df.head(3)
# Out:
#    id                 title        city postalCode   latitude  longitude  \
# 0   0  West-Varkenoordseweg   Rotterdam     3074HN  51.896601   4.514993
# 1   3           Ruiterakker       Assen     9407BG  53.013494   6.561012
# 2   8          Brusselseweg  Maastricht     6217GX  50.860841   5.671673
#
#    areaSqm                       firstSeenAt  \
# 0       14  2019-07-14 11:25:46.511000+00:00
# 1       16  2019-07-14 11:25:46.988000+00:00
# 2       16  2019-07-14 11:25:47.814000+00:00
#
#                          lastSeenAt isRoomActive  ... living pets  \
# 0  2019-07-26 22:18:23.142000+00:00         True  ...    NaN   No
# 1  2019-07-18 22:00:31.174000+00:00        False  ...    NaN   No
# 2  2019-08-10 00:14:27.130000+00:00         True  ...    NaN   No
#
#   smokingInside             matchAge    matchGender matchCapacity  \
# 0            No  16 years - 99 years  Not important      1 person
# 1           Yes  18 years - 32 years         Female      1 person
# 2            No  16 years - 40 years           Male     4 persons
#
#   matchLanguages               matchStatus  \
# 0  Not important             Not important
# 1  Not important  Student, Working student
# 2  Dutch English                   Student
#
#                                        coverImageUrl rent
# 0  https://resources.kamernet.nl/image/913b4b03-5...  500
# 1  https://resources.kamernet.nl/image/84e95365-6...  290
# 2  https://resources.kamernet.nl/image/6e625591-d...  425
#
# [3 rows x 34 columns]

# %%
df.dtypes
# Out:
# id                            int64
# title                        object
# city                         object
# postalCode                   object
# latitude                    float64
# longitude                   float64
# areaSqm                       int64
# firstSeenAt                  object
# lastSeenAt                   object
# isRoomActive                 object
# rawAvailability              object
# postedAgo                    object
# descriptionNonTranslated     object
# descriptionTranslated        object
# rentDetail                   object
# propertyType                 object
# furnish                      object
# energyLabel                  object
# gender                       object
# internet                     object
# roommates                    object
# shower                       object
# toilet                       object
# kitchen                      object
# living                       object
# pets                         object
# smokingInside                object
# matchAge                     object
# matchGender                  object
# matchCapacity                object
# matchLanguages               object
# matchStatus                  object
# coverImageUrl                object
# rent                          int64
# dtype: object

# %% [markdown]
# #### Analisis de variables categoricas

# %%
df_cat=df[[i for i in df.columns if i not in ['areaSqm','rent']]]

# %%
df_cat.columns
# Out:
# Index(['id', 'title', 'city', 'postalCode', 'latitude', 'longitude',
#        'firstSeenAt', 'lastSeenAt', 'isRoomActive', 'rawAvailability',
#        'postedAgo', 'descriptionNonTranslated', 'descriptionTranslated',
#        'rentDetail', 'propertyType', 'furnish', 'energyLabel', 'gender',
#        'internet', 'roommates', 'shower', 'toilet', 'kitchen', 'living',
#        'pets', 'smokingInside', 'matchAge', 'matchGender', 'matchCapacity',
#        'matchLanguages', 'matchStatus', 'coverImageUrl'],
#       dtype='object')

# %% [markdown]
# Podemos eliminar las columnas que no se utilizaran, en este caso, unicamente la de coverImageUrl

# %%
df_cat.head(3)
# Out:
#    id                 title        city postalCode   latitude  longitude  \
# 0   0  West-Varkenoordseweg   Rotterdam     3074HN  51.896601   4.514993
# 1   3           Ruiterakker       Assen     9407BG  53.013494   6.561012
# 2   8          Brusselseweg  Maastricht     6217GX  50.860841   5.671673
#
#                         firstSeenAt                        lastSeenAt  \
# 0  2019-07-14 11:25:46.511000+00:00  2019-07-26 22:18:23.142000+00:00
# 1  2019-07-14 11:25:46.988000+00:00  2019-07-18 22:00:31.174000+00:00
# 2  2019-07-14 11:25:47.814000+00:00  2019-08-10 00:14:27.130000+00:00
#
#   isRoomActive                rawAvailability  ... kitchen living pets  \
# 0         True  26-06-'19 - Indefinite period  ...  Shared    NaN   No
# 1        False  16-06-'19 - Indefinite period  ...  Shared    NaN   No
# 2         True  15-07-'19 - Indefinite period  ...  Shared    NaN   No
#
#   smokingInside             matchAge    matchGender matchCapacity  \
# 0            No  16 years - 99 years  Not important      1 person
# 1           Yes  18 years - 32 years         Female      1 person
# 2            No  16 years - 40 years           Male     4 persons
#
#   matchLanguages               matchStatus  \
# 0  Not important             Not important
# 1  Not important  Student, Working student
# 2  Dutch English                   Student
#
#                                        coverImageUrl
# 0  https://resources.kamernet.nl/image/913b4b03-5...
# 1  https://resources.kamernet.nl/image/84e95365-6...
# 2  https://resources.kamernet.nl/image/6e625591-d...
#
# [3 rows x 32 columns]

# %%
df_cat['firstSeenAt']=df_cat['firstSeenAt'].apply(lambda x: x[:10])
df_cat['lastSeenAt']=df_cat['lastSeenAt'].apply(lambda x: x[:10])
# Out:
# <ipython-input-15-d996c17bb9c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat['firstSeenAt']=df_cat['firstSeenAt'].apply(lambda x: x[:10])
# <ipython-input-15-d996c17bb9c7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat['lastSeenAt']=df_cat['lastSeenAt'].apply(lambda x: x[:10])

# %%
df_cat['firstSeenAt']=pd.to_datetime(df_cat['firstSeenAt'])
df_cat['lastSeenAt']=pd.to_datetime(df_cat['lastSeenAt'])
df_cat['tiempo_publicacion']=df_cat['lastSeenAt']-df_cat['firstSeenAt']
# Out:
# <ipython-input-16-f3a68f46a814>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat['firstSeenAt']=pd.to_datetime(df_cat['firstSeenAt'])
# <ipython-input-16-f3a68f46a814>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat['lastSeenAt']=pd.to_datetime(df_cat['lastSeenAt'])
# <ipython-input-16-f3a68f46a814>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat['tiempo_publicacion']=df_cat['lastSeenAt']-df_cat['firstSeenAt']

# %%
df_cat['tiempo_publicacion'] = df_cat['tiempo_publicacion'].dt.days
# Out:
# <ipython-input-17-24dcfe767180>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat['tiempo_publicacion'] = df_cat['tiempo_publicacion'].dt.days

# %%
df_cat.drop(columns=['coverImageUrl','firstSeenAt','lastSeenAt','postalCode','rawAvailability', 'postedAgo', ],inplace=True)
# Out:
# <ipython-input-18-ed58cb4f8132>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat.drop(columns=['coverImageUrl','firstSeenAt','lastSeenAt','postalCode','rawAvailability', 'postedAgo', ],inplace=True)

# %%
df_cat_num=df_cat[['id','tiempo_publicacion']]

# %%
df_cat.set_index('id',inplace=True)

# %%
## Frecuencia absoluta y relativa
for i in df_cat.columns:
  print(f'Variable: {i}')
  print(df_cat[i].value_counts())
  print(df_cat[i].value_counts(normalize=True))
  print('\n')
# Out:
# Variable: title
# title
# Hoogstraat             99
# Oldenzaalsestraat      84
# Hoofdstraat            67
# Friesestraatweg        65
# Kerkstraat             65
#                        ..
# Archimedesstraat        1
# Betjakstraat            1
# Sutan Sjahrirstraat     1
# Sabangstraat            1
# Lange Herenvest         1
# Name: count, Length: 7922, dtype: int64
# title
# Hoogstraat             0.003546
# Oldenzaalsestraat      0.003009
# Hoofdstraat            0.002400
# Friesestraatweg        0.002328
# Kerkstraat             0.002328
#                          ...
# Archimedesstraat       0.000036
# Betjakstraat           0.000036
# Sutan Sjahrirstraat    0.000036
# Sabangstraat           0.000036
# Lange Herenvest        0.000036
# Name: proportion, Length: 7922, dtype: float64
#
#
# Variable: city
# city
# Amsterdam         4856
# Groningen         3051
# Rotterdam         2684
# Enschede          1380
# Den Haag          1315
#                   ...
# Riel                 1
# Plasmolen            1
# Sprang-Capelle       1
# Middelburg           1
# Prinsenbeek          1
# Name: count, Length: 542, dtype: int64
# city
# Amsterdam         0.173957
# Groningen         0.109296
# Rotterdam         0.096149
# Enschede          0.049436
# Den Haag          0.047107
#                     ...
# Riel              0.000036
# Plasmolen         0.000036
# Sprang-Capelle    0.000036
# Middelburg        0.000036
# Prinsenbeek       0.000036
# Name: proportion, Length: 542, dtype: float64
#
#
# Variable: latitude
# latitude
# 52.395059    48
# 53.221738    33
# 52.319012    31
# 53.223893    31
# 51.935218    30
#              ..
# 52.127158     1
# 52.318471     1
# 52.078347     1
# 51.423478     1
# 52.084862     1
# Name: count, Length: 13717, dtype: int64
# latitude
# 52.395059    0.001720
# 53.221738    0.001182
# 52.319012    0.001111
# 53.223893    0.001111
# 51.935218    0.001075
#                ...
# 52.127158    0.000036
# 52.318471    0.000036
# 52.078347    0.000036
# 51.423478    0.000036
# 52.084862    0.000036
# Name: proportion, Length: 13717, dtype: float64
#
#
# Variable: longitude
# longitude
# 4.948125    48
# 6.539782    33
# 4.979117    31
# 6.590579    31
# 4.592372    30
#             ..
# 4.893805     1
# 4.883532     1
# 4.376455     1
# 5.070357     1
# 5.123071     1
# Name: count, Length: 13783, dtype: int64
# longitude
# 4.948125    0.001720
# 6.539782    0.001182
# 4.979117    0.001111
# 6.590579    0.001111
# 4.592372    0.001075
#               ...
# 4.893805    0.000036
# 4.883532    0.000036
# 4.376455    0.000036
# 5.070357    0.000036
# 5.123071    0.000036
# Name: proportion, Length: 13783, dtype: float64
#
#
# Variable: isRoomActive
# isRoomActive
# True     26374
# False     1478
# Name: count, dtype: int64
# isRoomActive
# True     0.946934
# False    0.053066
# Name: proportion, dtype: float64
#
#
# Variable: descriptionNonTranslated
# descriptionNonTranslated
# .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                30
# Nette kamer te huur in een levendige omgeving. Dichtbij vele voorzieningen zoals de UT, Saxion,centrum, winkels, eetgelegenheden, Metropool. Kortom alles op loop en fietsafstand.Rustige medebewoners , mede gebruik van keuken , veel gemeenschappelijke ruimtes zoals een woonkamer, inbouwkeuken, washok, hallen, tuin en zelfs een eigen fietsenstalling. Inschrijven is mogelijkAlle kamers zijn gemeubileerd en gestoffeerd op te leveren                                                                                                                                                                                                                                                                                                 24
# -                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                22
# For rent immediately for students all public facilities such as bus, train within walking distance of the HZ. Mall and beach also within walking distance. By agreement contract is made and documents are requested. House rules are respected. Response by mail or mobile.Thanks in advance.                                                                                                                                                                                                                                                                                                                                                                                                                                                   17
# MONDAY VIEWING A cosy studenthouse is the center of The Hague | several rooms available | public travel and supermarket on walking distance | room sizes (10m² to 18m²) and prices vary (€375 to €425) |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         16
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ..
# TE HUUR EEN RUIME KAMER  IN HET CENTRUM VAN LEIDEN. Locatie: Van der Werfstraat  BESCHIKBAAR PER 1 APRIL AANSTAANDEDeze kamer (ongeveer 13m²) heeft centrale verwarming en bevindt zich op de tweede verdieping van een gezellig studentenhuis.  Internet en TV zijn aanwezig.Huurprijs kamer € 300,00 per maand exclusief energie- en servicekosten ad € 75,00 per maand. . Keuken wordt gedeeld met één persoon.Douche en toilet worden gedeeld met 3 personen. Inschrijving Gemeente Leiden toegestaan                                                                                                                                                                                                                                         1
# Per direct een woning te huur                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Stylish and new renovated apartment with one bedroom available in fancy area city center! Available for 1 month in November for 1 person €775 or for a couple € 950.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# For rent: room in quiet area in Baarlo. You have your private bathroom. Toilet, kitchen and living room are shared with me. I am a quiet person and I expect that my guests are quiet too.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Private room in apartment available from now!The neighborhoodThe apartment is located in a very nice, strategic and central part of Rotterdam. It's in front of the central station (4 minutes on walk), so it's perfect for students and young professionals.Nearby the house, you can find many restaurants, bars, cinemas and pubs but also grocery shops and supermarkets (such as ALDI) for your daily needs. The houseThe house, that will be shared by 5 people, is composed of:- a very well equipped kitchen- a living room - 5 single rooms- bathrooms (3 showers, 2 toilettes)In the room there are a single bed, a desk, a chair, a bedside table with a little lamp and a lot of closet space.Let me know if you want a viewing.     1
# Name: count, Length: 24034, dtype: int64
# descriptionNonTranslated
# .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.001079
# Nette kamer te huur in een levendige omgeving. Dichtbij vele voorzieningen zoals de UT, Saxion,centrum, winkels, eetgelegenheden, Metropool. Kortom alles op loop en fietsafstand.Rustige medebewoners , mede gebruik van keuken , veel gemeenschappelijke ruimtes zoals een woonkamer, inbouwkeuken, washok, hallen, tuin en zelfs een eigen fietsenstalling. Inschrijven is mogelijkAlle kamers zijn gemeubileerd en gestoffeerd op te leveren                                                                                                                                                                                                                                                                                                 0.000863
# -                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.000791
# For rent immediately for students all public facilities such as bus, train within walking distance of the HZ. Mall and beach also within walking distance. By agreement contract is made and documents are requested. House rules are respected. Response by mail or mobile.Thanks in advance.                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.000611
# MONDAY VIEWING A cosy studenthouse is the center of The Hague | several rooms available | public travel and supermarket on walking distance | room sizes (10m² to 18m²) and prices vary (€375 to €425) |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.000575
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# TE HUUR EEN RUIME KAMER  IN HET CENTRUM VAN LEIDEN. Locatie: Van der Werfstraat  BESCHIKBAAR PER 1 APRIL AANSTAANDEDeze kamer (ongeveer 13m²) heeft centrale verwarming en bevindt zich op de tweede verdieping van een gezellig studentenhuis.  Internet en TV zijn aanwezig.Huurprijs kamer € 300,00 per maand exclusief energie- en servicekosten ad € 75,00 per maand. . Keuken wordt gedeeld met één persoon.Douche en toilet worden gedeeld met 3 personen. Inschrijving Gemeente Leiden toegestaan                                                                                                                                                                                                                                        0.000036
# Per direct een woning te huur                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0.000036
# Stylish and new renovated apartment with one bedroom available in fancy area city center! Available for 1 month in November for 1 person €775 or for a couple € 950.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0.000036
# For rent: room in quiet area in Baarlo. You have your private bathroom. Toilet, kitchen and living room are shared with me. I am a quiet person and I expect that my guests are quiet too.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.000036
# Private room in apartment available from now!The neighborhoodThe apartment is located in a very nice, strategic and central part of Rotterdam. It's in front of the central station (4 minutes on walk), so it's perfect for students and young professionals.Nearby the house, you can find many restaurants, bars, cinemas and pubs but also grocery shops and supermarkets (such as ALDI) for your daily needs. The houseThe house, that will be shared by 5 people, is composed of:- a very well equipped kitchen- a living room - 5 single rooms- bathrooms (3 showers, 2 toilettes)In the room there are a single bed, a desk, a chair, a bedside table with a little lamp and a lot of closet space.Let me know if you want a viewing.    0.000036
# Name: proportion, Length: 24034, dtype: float64
#
#
# Variable: descriptionTranslated
# descriptionTranslated
# .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    28
# -                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    21
# For rent immediately for students all public facilities such as bus, train within walking distance of the HZ. Mall and beach also within walking distance. By agreement contract is made and documents are requested. House rules are respected. Response by mail or mobile.Thanks in advance.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       17
# MONDAY VIEWING A cosy studenthouse is the center of The Hague | several rooms available | public travel and supermarket on walking distance | room sizes (10m² to 18m²) and prices vary (€375 to €425) |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             16
# heel mooi kamer en 100% netjes te huur in Arnhem dichtbij de scholen HAN en Rijn IJssel ,weinig ander mensen in woning , maximaal 1 , er zijn weinig ander kamers te huur die zo netjes met prachtig badkamer en prachtig keuken (vetwasser aanwezig ) .wees maar snel                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               13
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ..
# Nice furnished one-bedroom apartment available. The location is ideal; around the corner of the Julianapark where you can relax in the summer and winter. The shops on the Amsterdamsestraatweg are within walking distance, also station Zuilen, public transport and exit roads, A2. You are within 5 minutes cycling in the center of Utrecht and Maarssen.layout:Entrance hall, stairs to the second floor. Spacious living room with open kitchen. The kitchen gives access to the bathroom and the sunny roofterrace of 12 m2. The kitchen has a hob, extractor fan and fridge. The bedroom is located at the front of the property. The bathroom is equipped with shower, sink, toilet and washing machine.Free parking!Features:-available from September 15th, 2019, for at least 12 months and amaximum of 24 months;-the rent is € 1150,- including gas, water, cable and internet and excluding electricity;-completion furnished;-only suitable for 1 working expat.                                                                                                                                                                                                                                                                     1
# Royale studentenkamer nabij centrum.De kamer komt vrij per 1 Oktober maar is in overleg eerder te betrekken. De kamer is voorzien van centrale verwarming, wastafel, veel daglicht en een fietsenberging. De keuken, wc en douche liggen gelijkvloers met de kamer en deel je met drie andere studenten.De huurprijs is inclusief alles; gas, water, electriciteit, wifi en bekabeld internet(supersnel glasvezel f.t.t.h.), Netflix, Videoland, fornuis, magnetron, wasmachine, koelkast, stofzuiger, senseo, afvalstoffenheffing, ingezetenenheffing, verontreinigingsheffing en rioolrecht(gebruikersdeel). Het huis is voorzien van gekoppelde rookmelders.Naast de 18m2 van de kamer beschik je ook nog over 10m2 gezamelijke ruimte van keuken, wc en douche.De kamer ligt op een ideale locatie. Het station is 8 minuten lopen, het centrum 4, en in 6 minuten wandel je naar van Hall Larenstein. NHL Stenden is 7 minuten op de fiets. Het huis is bestemd voor studenten van NHL Stenden en Van Hall Larenstein(campuscontract).Vertel kort iets over jezelf, je studie en wat verder het vermelden waard is. En voeg ook je telefoonnummer toe. Wie weet nodigen we je uit voor een nadere kennismaking en bezichtiging van de kamer.     1
# Sorry guys, deze kamer is alleen voor vrouwen!De kamer komt vrij per 1 oktober 2019. Het is een grote kamer incl. klein balkon. Je deelt de ruime badkamer, keuken en wc met een ander meisje.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Een mooie kamer, dichtbij het UMCG. Heeft een eigen keuken en toilet op de zelfde verdieping. Rustig huis met aardige huisgenoten. Geen verplichte huisavonden.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# Private room in apartment available from now!The neighborhoodThe apartment is located in a very nice, strategic and central part of Rotterdam. It's in front of the central station (4 minutes on walk), so it's perfect for students and young professionals.Nearby the house, you can find many restaurants, bars, cinemas and pubs but also grocery shops and supermarkets (such as ALDI) for your daily needs. The houseThe house, that will be shared by 5 people, is composed of:- a very well equipped kitchen- a living room - 5 single rooms- bathrooms (3 showers, 2 toilettes)In the room there are a single bed, a desk, a chair, a bedside table with a little lamp and a lot of closet space.Let me know if you want a viewing.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# Name: count, Length: 14927, dtype: int64
# descriptionTranslated
# .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0.001575
# -                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0.001181
# For rent immediately for students all public facilities such as bus, train within walking distance of the HZ. Mall and beach also within walking distance. By agreement contract is made and documents are requested. House rules are respected. Response by mail or mobile.Thanks in advance.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.000956
# MONDAY VIEWING A cosy studenthouse is the center of The Hague | several rooms available | public travel and supermarket on walking distance | room sizes (10m² to 18m²) and prices vary (€375 to €425) |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0.000900
# heel mooi kamer en 100% netjes te huur in Arnhem dichtbij de scholen HAN en Rijn IJssel ,weinig ander mensen in woning , maximaal 1 , er zijn weinig ander kamers te huur die zo netjes met prachtig badkamer en prachtig keuken (vetwasser aanwezig ) .wees maar snel                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.000731
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# Nice furnished one-bedroom apartment available. The location is ideal; around the corner of the Julianapark where you can relax in the summer and winter. The shops on the Amsterdamsestraatweg are within walking distance, also station Zuilen, public transport and exit roads, A2. You are within 5 minutes cycling in the center of Utrecht and Maarssen.layout:Entrance hall, stairs to the second floor. Spacious living room with open kitchen. The kitchen gives access to the bathroom and the sunny roofterrace of 12 m2. The kitchen has a hob, extractor fan and fridge. The bedroom is located at the front of the property. The bathroom is equipped with shower, sink, toilet and washing machine.Free parking!Features:-available from September 15th, 2019, for at least 12 months and amaximum of 24 months;-the rent is € 1150,- including gas, water, cable and internet and excluding electricity;-completion furnished;-only suitable for 1 working expat.                                                                                                                                                                                                                                                                    0.000056
# Royale studentenkamer nabij centrum.De kamer komt vrij per 1 Oktober maar is in overleg eerder te betrekken. De kamer is voorzien van centrale verwarming, wastafel, veel daglicht en een fietsenberging. De keuken, wc en douche liggen gelijkvloers met de kamer en deel je met drie andere studenten.De huurprijs is inclusief alles; gas, water, electriciteit, wifi en bekabeld internet(supersnel glasvezel f.t.t.h.), Netflix, Videoland, fornuis, magnetron, wasmachine, koelkast, stofzuiger, senseo, afvalstoffenheffing, ingezetenenheffing, verontreinigingsheffing en rioolrecht(gebruikersdeel). Het huis is voorzien van gekoppelde rookmelders.Naast de 18m2 van de kamer beschik je ook nog over 10m2 gezamelijke ruimte van keuken, wc en douche.De kamer ligt op een ideale locatie. Het station is 8 minuten lopen, het centrum 4, en in 6 minuten wandel je naar van Hall Larenstein. NHL Stenden is 7 minuten op de fiets. Het huis is bestemd voor studenten van NHL Stenden en Van Hall Larenstein(campuscontract).Vertel kort iets over jezelf, je studie en wat verder het vermelden waard is. En voeg ook je telefoonnummer toe. Wie weet nodigen we je uit voor een nadere kennismaking en bezichtiging van de kamer.    0.000056
# Sorry guys, deze kamer is alleen voor vrouwen!De kamer komt vrij per 1 oktober 2019. Het is een grote kamer incl. klein balkon. Je deelt de ruime badkamer, keuken en wc met een ander meisje.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.000056
# Een mooie kamer, dichtbij het UMCG. Heeft een eigen keuken en toilet op de zelfde verdieping. Rustig huis met aardige huisgenoten. Geen verplichte huisavonden.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.000056
# Private room in apartment available from now!The neighborhoodThe apartment is located in a very nice, strategic and central part of Rotterdam. It's in front of the central station (4 minutes on walk), so it's perfect for students and young professionals.Nearby the house, you can find many restaurants, bars, cinemas and pubs but also grocery shops and supermarkets (such as ALDI) for your daily needs. The houseThe house, that will be shared by 5 people, is composed of:- a very well equipped kitchen- a living room - 5 single rooms- bathrooms (3 showers, 2 toilettes)In the room there are a single bed, a desk, a chair, a bedside table with a little lamp and a lot of closet space.Let me know if you want a viewing.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.000056
# Name: proportion, Length: 14927, dtype: float64
#
#
# Variable: rentDetail
# rentDetail
# Utilities incl.    20019
# Name: count, dtype: int64
# rentDetail
# Utilities incl.    1.0
# Name: proportion, dtype: float64
#
#
# Variable: propertyType
# propertyType
# Room                 18168
# Apartment             7103
# Studio                2454
# Anti-squat             187
# Student residence        3
# Name: count, dtype: int64
# propertyType
# Room                 0.650833
# Apartment            0.254451
# Studio               0.087910
# Anti-squat           0.006699
# Student residence    0.000107
# Name: proportion, dtype: float64
#
#
# Variable: furnish
# furnish
# Furnished      12534
# Unfurnished    11498
# Uncarpeted      3669
# Name: count, dtype: int64
# furnish
# Furnished      0.452475
# Unfurnished    0.415075
# Uncarpeted     0.132450
# Name: proportion, dtype: float64
#
#
# Variable: energyLabel
# energyLabel
# Unknown    23705
# A           2026
# B            813
# C            650
# D            335
# E            137
# F             98
# G             88
# Name: count, dtype: int64
# energyLabel
# Unknown    0.851106
# A          0.072742
# B          0.029190
# C          0.023338
# D          0.012028
# E          0.004919
# F          0.003519
# G          0.003160
# Name: proportion, dtype: float64
#
#
# Variable: gender
# gender
# Unknown    11217
# Mixed       7880
# Female      4387
# Male        3895
# Name: count, dtype: int64
# gender
# Unknown    0.409694
# Mixed      0.287812
# Female     0.160232
# Male       0.142262
# Name: proportion, dtype: float64
#
#
# Variable: internet
# internet
# Yes        21322
# Unknown     4863
# No          1667
# Name: count, dtype: int64
# internet
# Yes        0.765546
# Unknown    0.174601
# No         0.059852
# Name: proportion, dtype: float64
#
#
# Variable: roommates
# roommates
# Unknown        6253
# 2              4390
# 1              3782
# 3              3764
# 4              2138
# 5              1195
# More than 8     932
# 6               490
# 7               306
# 8               283
# Name: count, dtype: int64
# roommates
# Unknown        0.265712
# 2              0.186547
# 1              0.160710
# 3              0.159946
# 4              0.090851
# 5              0.050780
# More than 8    0.039604
# 6              0.020822
# 7              0.013003
# 8              0.012026
# Name: proportion, dtype: float64
#
#
# Variable: shower
# shower
# Shared     17107
# Own         6165
# Unknown     4562
# Name: count, dtype: int64
# shower
# Shared     0.614608
# Own        0.221492
# Unknown    0.163900
# Name: proportion, dtype: float64
#
#
# Variable: toilet
# toilet
# Shared     17133
# Own         6126
# Unknown     4576
# Name: count, dtype: int64
# toilet
# Shared     0.615520
# Own        0.220083
# Unknown    0.164397
# Name: proportion, dtype: float64
#
#
# Variable: kitchen
# kitchen
# Shared     16363
# Own         6744
# Unknown     4560
# Name: count, dtype: int64
# kitchen
# Shared     0.591427
# Own        0.243756
# Unknown    0.164817
# Name: proportion, dtype: float64
#
#
# Variable: living
# living
# Shared     9298
# Own        7218
# Unknown    5103
# Name: count, dtype: int64
# living
# Shared     0.430085
# Own        0.333873
# Unknown    0.236042
# Name: proportion, dtype: float64
#
#
# Variable: pets
# pets
# No                     25509
# By mutual agreement     1225
# Yes                     1118
# Name: count, dtype: int64
# pets
# No                     0.915877
# By mutual agreement    0.043982
# Yes                    0.040141
# Name: proportion, dtype: float64
#
#
# Variable: smokingInside
# smokingInside
# No               23717
# Yes               2137
# Not important     1998
# Name: count, dtype: int64
# smokingInside
# No               0.851537
# Yes              0.076727
# Not important    0.071736
# Name: proportion, dtype: float64
#
#
# Variable: matchAge
# matchAge
# 16 years - 99 years              7629
# Not important - Not important    3673
# 18 years - 35 years              1097
# 18 years - 40 years               734
# 18 years - 30 years               719
#                                  ...
# 32 years - 65 years                 1
# 18 years - 53 years                 1
# 16 years - 96 years                 1
# 26 years - 66 years                 1
# 16 years - 85 years                 1
# Name: count, Length: 645, dtype: int64
# matchAge
# 16 years - 99 years              0.273912
# Not important - Not important    0.131876
# 18 years - 35 years              0.039387
# 18 years - 40 years              0.026354
# 18 years - 30 years              0.025815
#                                    ...
# 32 years - 65 years              0.000036
# 18 years - 53 years              0.000036
# 16 years - 96 years              0.000036
# 26 years - 66 years              0.000036
# 16 years - 85 years              0.000036
# Name: proportion, Length: 645, dtype: float64
#
#
# Variable: matchGender
# matchGender
# Not important    20597
# Female            5247
# Male              1911
# Mixed               97
# Name: count, dtype: int64
# matchGender
# Not important    0.739516
# Female           0.188389
# Male             0.068613
# Mixed            0.003483
# Name: proportion, dtype: float64
#
#
# Variable: matchCapacity
# matchCapacity
# 1 person         18363
# 2 persons         6190
# Not important     1669
# 3 persons          651
# 4 persons          567
# > 5 persons        239
# 5 persons          173
# Name: count, dtype: int64
# matchCapacity
# 1 person         0.659306
# 2 persons        0.222246
# Not important    0.059924
# 3 persons        0.023374
# 4 persons        0.020358
# > 5 persons      0.008581
# 5 persons        0.006211
# Name: proportion, dtype: float64
#
#
# Variable: matchLanguages
# matchLanguages
# Not important                                                                                                                                               19207
# Dutch                                                                                                                                                        3229
# Dutch English                                                                                                                                                2469
# Dutch English Spanish French Italian German Portuguese Chinese Russian Japanese Hindi Bengali Korean Turkish Vietnamese Polish Arabic Romanian + 16 more      987
# Dutch English German                                                                                                                                          453
#                                                                                                                                                             ...
# English Spanish Italian German Russian                                                                                                                          1
# Dutch English Italian Portuguese Japanese Polish                                                                                                                1
# English Russian Polish                                                                                                                                          1
# Dutch English German Turkish                                                                                                                                    1
# Dutch English Spanish French Italian German Portuguese Chinese Romanian                                                                                         1
# Name: count, Length: 144, dtype: int64
# matchLanguages
# Not important                                                                                                                                               0.689609
# Dutch                                                                                                                                                       0.115934
# Dutch English                                                                                                                                               0.088647
# Dutch English Spanish French Italian German Portuguese Chinese Russian Japanese Hindi Bengali Korean Turkish Vietnamese Polish Arabic Romanian + 16 more    0.035437
# Dutch English German                                                                                                                                        0.016265
#                                                                                                                                                               ...
# English Spanish Italian German Russian                                                                                                                      0.000036
# Dutch English Italian Portuguese Japanese Polish                                                                                                            0.000036
# English Russian Polish                                                                                                                                      0.000036
# Dutch English German Turkish                                                                                                                                0.000036
# Dutch English Spanish French Italian German Portuguese Chinese Romanian                                                                                     0.000036
# Name: proportion, Length: 144, dtype: float64
#
#
# Variable: matchStatus
# matchStatus
# Not important                                           7832
# Student, Working student, Working                       5032
# Student, Working student                                3678
# Student, Working student, Working, Looking for a job    3234
# Student                                                 2989
# Working                                                 2184
# Working student, Working                                1938
# Working student, Working, Looking for a job              378
# Working student                                          269
# Working, Looking for a job                               161
# Student, Working                                          67
# Student, Working student, Looking for a job               49
# Looking for a job                                         24
# Student, Looking for a job                                10
# Working student, Looking for a job                         4
# Student, Working, Looking for a job                        3
# Name: count, dtype: int64
# matchStatus
# Not important                                           0.281201
# Student, Working student, Working                       0.180669
# Student, Working student                                0.132055
# Student, Working student, Working, Looking for a job    0.116114
# Student                                                 0.107317
# Working                                                 0.078414
# Working student, Working                                0.069582
# Working student, Working, Looking for a job             0.013572
# Working student                                         0.009658
# Working, Looking for a job                              0.005781
# Student, Working                                        0.002406
# Student, Working student, Looking for a job             0.001759
# Looking for a job                                       0.000862
# Student, Looking for a job                              0.000359
# Working student, Looking for a job                      0.000144
# Student, Working, Looking for a job                     0.000108
# Name: proportion, dtype: float64
#
#
# Variable: tiempo_publicacion
# tiempo_publicacion
# 30     3339
# 0      1683
# 2      1421
# 5      1374
# 3      1332
#        ...
# 207       1
# 121       1
# 209       1
# 201       1
# 158       1
# Name: count, Length: 167, dtype: int64
# tiempo_publicacion
# 30     0.119613
# 0      0.060290
# 2      0.050905
# 5      0.049221
# 3      0.047716
#          ...
# 207    0.000036
# 121    0.000036
# 209    0.000036
# 201    0.000036
# 158    0.000036
# Name: proportion, Length: 167, dtype: float64

# %%
#@title Usaremos crosstab para identificar relaciones entre algunas variables categoricas identificadas

print(pd.crosstab(df_cat['gender'], df_cat['furnish']))
print("\n")
print(pd.crosstab(df_cat['gender'], df_cat['pets']))
print("\n")
print(pd.crosstab(df_cat['gender'], df_cat['smokingInside']))
print("\n")
print(pd.crosstab(df_cat['rentDetail'], df_cat['gender']))
# Out:
# furnish  Furnished  Uncarpeted  Unfurnished
# gender
# Female        2167         563         1656
# Male          2017         550         1327
# Mixed         3382        1345         3150
# Unknown       4727        1180         5101
#
#
# pets     By mutual agreement    No  Yes
# gender
# Female                    81  4154  152
# Male                      58  3664  173
# Mixed                    102  7535  243
# Unknown                  890  9799  528
#
#
# smokingInside    No  Not important  Yes
# gender
# Female         3962            220  205
# Male           3275            186  434
# Mixed          6756            379  745
# Unknown        9379           1095  743
#
#
# gender           Female  Male  Mixed  Unknown
# rentDetail
# Utilities incl.    3874  3351   6971     5536

# %% [markdown]
# Con esta funcion mas adelante trataremos los datos nulos y le daremos a la variable resultado un valor categorico para ajustar mejor los modelos de ML.

# %%
#Al tener copntexto de los datos vamos a resolver los problemas de nulos
def data_prep(df):
    df['rentDetail'].replace(np.nan, 'Non Utilities Incl.',inplace=True)
    df['furnish'].replace(np.nan,'Unfurnished',inplace=True)
    df['gender'].replace('Unknown','Mixed',inplace=True)
    df['internet'].replace('Unknown','No',inplace=True)
    for i in ['shower','toilet','living','kitchen']:
        df[i].replace('Unknown','Shared',inplace=True)
    df['smokingInside'].replace('Not Important','Yes',inplace=True)
    try:
        y=pd.qcut(df['rent'], 4, labels=[0,1,2,3], retbins=False, precision=3, duplicates='raise').values
    except :
        y=None
    pre_x=df[['areaSqm','rentDetail','propertyType','furnish','gender','internet','shower','toilet','kitchen','living','pets','smokingInside']]
    x=pd.get_dummies(pre_x,prefix_sep='_',
                columns=['rentDetail','propertyType','furnish','gender','internet','shower','toilet','kitchen','living','pets','smokingInside'],
                sparse=False, drop_first=True, dtype=None)
    return x,y

# %% [markdown]
# #### Analisis Numerico

# %% [markdown]
# Al id, latitud y longitud ser variables cuya numericidad se comprota diferente, no las tendremos en cuenta a la hora de hacer el analisis nume

# %%
df_numerico=df[['id','areaSqm','rent']]
df_num = pd.merge(df_numerico, df_cat_num, on='id', how='inner')

# %%
# Análisis Descriptivo de las variables numericas relevantes
#df_num.set_index('id',inplace=True)
df_num.describe()
# Out:
#                  id       areaSqm          rent  tiempo_publicacion
# count  27915.000000  27915.000000  27915.000000        27915.000000
# mean   23345.617374     31.667240    669.505212           15.995450
# std    13456.767709     29.727405    416.156758           18.856033
# min        0.000000      6.000000      1.000000            0.000000
# 25%    11706.500000     14.000000    395.000000            4.000000
# 50%    23316.000000     20.000000    550.000000           11.000000
# 75%    34973.000000     40.000000    800.000000           26.000000
# max    46721.000000    600.000000   5999.000000          233.000000

# %%
#@title Analisis variable resultado (rent)
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(6, 6))
sns.kdeplot(
    df.rent,
    fill    = True,
    color   = "blue",
    ax      = axes[0]
)
sns.rugplot(
    df.rent,
    color   = "blue",
    ax      = axes[0]
)
axes[0].set_title("Distribución original", fontsize = 'medium')
axes[0].set_xlabel('Rent', fontsize='small')
axes[0].tick_params(labelsize = 6)

sns.kdeplot(
    np.sqrt(df.rent,),
    fill    = True,
    color   = "blue",
    ax      = axes[1]
)
sns.rugplot(
    np.sqrt(df.rent,),
    color   = "blue",
    ax      = axes[1]
)
axes[1].set_title("Transformación raíz cuadrada", fontsize = 'medium')
axes[1].set_xlabel('sqrt(rent)', fontsize='small')
axes[1].tick_params(labelsize = 6)

sns.kdeplot(
    np.log(df.rent,),
    fill    = True,
    color   = "blue",
    ax      = axes[2]
)
sns.rugplot(
    np.log(df.rent,),
    color   = "blue",
    ax      = axes[2]
)
axes[2].set_title("Transformación logarítmica", fontsize = 'medium')
axes[2].set_xlabel('log(rent)', fontsize='small')
axes[2].tick_params(labelsize = 6)

fig.tight_layout()

# %%
# Simetria y Curtosis
print('Asimetria:',df['rent'].skew().round(2), '  Curtosis:', df['rent'].kurt().round(2))
# Out:
# Asimetria: 2.36   Curtosis: 10.36

# %% [markdown]
# La asimetría te dice si los datos están equilibrados alrededor de la media, mientras que la curtosis te informa sobre la presencia de valores extremos. Ambas son esenciales para evaluar la forma de la distribución de una variable y tomar decisiones informadas sobre el análisis y la modelización de los datos.
#
# De los valores obtenidos podemos interpretar que:
#
# **Curtosis positiva:** La distribución tiene colas más pesadas y un pico más alto que una distribución normal. Esto indica una mayor presencia de valores extremos o outliers.
#
# **Asimetría positiva:** La cola derecha de la distribución es más larga o más pesada que la izquierda. Los valores tienden a estar más concentrados a la izquierda de la media.

# %%
#@title Analisis variable (areaSqm)
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(6, 6))
sns.kdeplot(
    df.areaSqm,
    fill    = True,
    color   = "blue",
    ax      = axes[0]
)
sns.rugplot(
    df.areaSqm,
    color   = "blue",
    ax      = axes[0]
)
axes[0].set_title("Distribución original", fontsize = 'medium')
axes[0].set_xlabel('areaSqm', fontsize='small')
axes[0].tick_params(labelsize = 6)

sns.kdeplot(
    np.sqrt(df.areaSqm,),
    fill    = True,
    color   = "blue",
    ax      = axes[1]
)
sns.rugplot(
    np.sqrt(df.areaSqm,),
    color   = "blue",
    ax      = axes[1]
)
axes[1].set_title("Transformación raíz cuadrada", fontsize = 'medium')
axes[1].set_xlabel('sqrt(areaSqm)', fontsize='small')
axes[1].tick_params(labelsize = 6)

sns.kdeplot(
    np.log(df.areaSqm,),
    fill    = True,
    color   = "blue",
    ax      = axes[2]
)
sns.rugplot(
    np.log(df.areaSqm,),
    color   = "blue",
    ax      = axes[2]
)
axes[2].set_title("Transformación logarítmica", fontsize = 'medium')
axes[2].set_xlabel('log(areaSqm)', fontsize='small')
axes[2].tick_params(labelsize = 6)

fig.tight_layout()

# %%
#@title Analisis variable (tiempo_publicacion)
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(6, 6))
sns.kdeplot(
    df_num.tiempo_publicacion,
    fill    = True,
    color   = "blue",
    ax      = axes[0]
)
sns.rugplot(
    df_num.tiempo_publicacion,
    color   = "blue",
    ax      = axes[0]
)
axes[0].set_title("Distribución original", fontsize = 'medium')
axes[0].set_xlabel('tiempo_publicacion', fontsize='small')
axes[0].tick_params(labelsize = 6)

sns.kdeplot(
    np.sqrt(df_num.tiempo_publicacion,),
    fill    = True,
    color   = "blue",
    ax      = axes[1]
)
sns.rugplot(
    np.sqrt(df_num.tiempo_publicacion,),
    color   = "blue",
    ax      = axes[1]
)
axes[1].set_title("Transformación raíz cuadrada", fontsize = 'medium')
axes[1].set_xlabel('sqrt(tiempo_publicacion)', fontsize='small')
axes[1].tick_params(labelsize = 6)

sns.kdeplot(
    np.log(df_num.tiempo_publicacion,),
    fill    = True,
    color   = "blue",
    ax      = axes[2]
)
sns.rugplot(
    np.log(df_num.tiempo_publicacion,),
    color   = "blue",
    ax      = axes[2]
)
axes[2].set_title("Transformación logarítmica", fontsize = 'medium')
axes[2].set_xlabel('log(tiempo_publicacion)', fontsize='small')
axes[2].tick_params(labelsize = 6)

fig.tight_layout()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#@title Gráfico de distribución para cada variable numérica

# Ajustar número de subplots en función del número de columnas
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(9, 5))
axes = axes.flat

for i, colum in enumerate(df_num.columns):
    sns.regplot(
        x = df_num[colum],
        y = df_num['rent'],
        color = "orange",
        marker = '.',
        scatter_kws = {"alpha":0.4},
        line_kws = {"color":"b","alpha":0.7},
        ax = axes[i]
    )
    axes[i].set_title(f"rent vs {colum}", fontsize = 7, fontweight = "bold")
    axes[i].ticklabel_format(style='sci', scilimits=(-4,4), axis='both')
    axes[i].yaxis.set_major_formatter(ticker.EngFormatter())
    axes[i].xaxis.set_major_formatter(ticker.EngFormatter())
    axes[i].tick_params(labelsize = 6)
    axes[i].set_xlabel("")
    axes[i].set_ylabel("")

fig.tight_layout()
plt.subplots_adjust(top=0.9)
fig.suptitle('Correlación con rent', fontsize = 10, fontweight = "bold");
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-4226d99017c7> in <cell line: 7>()
#      13         scatter_kws = {"alpha":0.4},
#      14         line_kws = {"color":"b","alpha":0.7},
# ---> 15         ax = axes[i]
#      16     )
#      17     axes[i].set_title(f"rent vs {colum}", fontsize = 7, fontweight = "bold")
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %% [markdown]
# Se observa una correlacion, sin embargo la presencia de outliers no se puede desconsiderar, por lo que se requerira del uso de las variables categoricas, el grafico de rent vs rent no tiene mucho sentido, sin embargo al ser una variable numerica, se uso.

# %%
df_num.corr()

# %% [markdown]
# Al darle numeros a la correlacion, encontramos un valor significativo, respondiendo a una de las preguntas, pudiendo decir que el precio del alquiler esta directamente relacionado a los metros cuadrados que tenga la propiedad, sin embargo los dias que dura la publicacion no parecen ser significativos

# %% [markdown]
# ## Ingenieria de atributos

# %%
#definimos una unica funcion para la transformacion de los campos para que se procesen mas facil en los modelos de ML
def data_prep(df):
  #Reemplazamos datos nulos
    df['rentDetail'].replace(np.nan, 'Non Utilities Incl.',inplace=True)
    df['furnish'].replace(np.nan,'Unfurnished',inplace=True)
    df['gender'].replace('Unknown','Mixed',inplace=True)
    df['internet'].replace('Unknown','No',inplace=True)
    for i in ['shower','toilet','living','kitchen']:
        df[i].replace('Unknown','Shared',inplace=True)
    df['smokingInside'].replace('Not Important','Yes',inplace=True)
    try:
        #Dividimos la variable objetivo en categorias dependiendo de sus cuartiles
        y=pd.qcut(df['rent'], 4, labels=[0,1,2,3], retbins=False, precision=3, duplicates='raise').values
    except :
        y=None
    pre_x=df[['areaSqm','rentDetail','propertyType','furnish','gender','internet','shower','toilet','kitchen','living','pets','smokingInside']]
    #Obtenemos variables dummies de los campos categoricos
    x=pd.get_dummies(pre_x,prefix_sep='_',
                columns=['rentDetail','propertyType','furnish','gender','internet','shower','toilet','kitchen','living','pets','smokingInside'],
                sparse=False, drop_first=True, dtype=None)
    return x,y

# %% [markdown]
# ### Modelos de ML
#
# Vamos a preparar la data para realizar modelos de ML

# %%
#Aplicamos la funcion de ingenieria de atributos

X_train,y_train=data_prep(df)
X_test,y_test=data_prep(df2)

# %% [markdown]
# ## Seleccion de modelos con Cross-Validation

# %%
models = [
    LogisticRegression(max_iter=1000),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    SVC(),
    XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    GradientBoostingClassifier()
]


# Evaluar cada modelo con cross-validation
for model in models:
  cv_scores = cross_val_score(model, X_train, y_train, cv=5)  # 5-fold cross-validation
  print(f"Modelo: {type(model).__name__}")
  print(f"Puntuaciones de validación cruzada: {cv_scores}")
  print(f"Puntuación media: {np.mean(cv_scores)}")
  print("-" * 20)

# %% [markdown]
# #### **Modelo: LogisticRegression / Puntuación media: 0.5590184488626186**
# Puntuaciones de validación cruzada: [0.57173563 0.54737596 0.56170518 0.5572273  0.55704818]
#
# --------------------
#
# #### **Modelo: DecisionTreeClassifier Puntuación media: 0.5603439011284256**
# Puntuaciones de validación cruzada: [0.56457102 0.55776464 0.56600394 0.56654129 0.54683862]
#
# --------------------
#
# #### **Modelo: RandomForestClassifier / Puntuación media: 0.56947877485223**
# Puntuaciones de validación cruzada: [0.57191474 0.5667204  0.5726312  0.56833244 0.56779509]
#
# --------------------
#
# #### **Modelo: SVC / Puntuación media: 0.5520687802256851**
# Puntuaciones de validación cruzada: [0.56403367 0.55095827 0.55167473 0.54468924 0.548988  ]
#
# --------------------
#
# #### **Modelo: XGBClassifier / Puntuación media: 0.5859573705892889**
# Puntuaciones de validación cruzada: [0.59448325 0.58534838 0.58767688 0.57979581 0.58248254]
#
#
# --------------------
#
# #### **Modelo: GradientBoostingClassifier / Puntuación media: 0.5799749238760523**
# Puntuaciones de validación cruzada: [0.59179653 0.57675085 0.578542   0.57675085 0.57603439]
#
# --------------------

# %% [markdown]
# # Por familiaridad con el modelo y Score medio se procedera a realizar los ajustes de PCA y GridSearch con el modelo XGBoost Classifier

# %% [markdown]
# # Ajustes del modelo (PCA y GridSearch)

# %%
# Suponiendo que X y y son tus datos de entrada y la variable objetivo
# Escalar los datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Aplicar PCA para reducir la dimensionalidad
pca = PCA(n_components=0.95)
X_train_pca = pca.fit_transform(X_train_scaled)

# Crear el modelo
model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# Realizar validación cruzada
cv_scores = cross_val_score(model, X_train_pca, y_train, cv=5)
print(f"Puntuaciones de validación cruzada: {cv_scores}")
print(f"Puntuación media: {np.mean(cv_scores)}")
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [03:28:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [03:28:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [03:28:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [03:28:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [03:28:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Puntuaciones de validación cruzada: [0.58337811 0.56994447 0.57657174 0.56869067 0.56349633]
# Puntuación media: 0.5724162636575317

# %%
len(X_train_pca[0])
# Out:
# 14

# %%
len(X_train.columns)
# Out:
# 19

# %% [markdown]
# _Solo se eliminaron unicamente 5 columnas en el PCA, lo que bajo el rendimiento del modelo un 1.5% por lo que se decidio proseguir con el resultado del analisis de componentes principales_

# %% [markdown]
# # Configuracion de hiperparametros y metricas de evaluacion

# %%
#modelo base
model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

#inicializamos el gridsearch
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0]
}

# configuraramos el GridSearchCV
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    verbose=2,
    n_jobs=-1
)

# aplicamos el gridsearch
grid_search.fit(X_train_pca, y_train)

print(f"Mejores parámetros: {grid_search.best_params_}")
print(f"Mejor puntuación de validación cruzada: {grid_search.best_score_}")
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:17:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Mejores parámetros: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'subsample': 0.8}
# Mejor puntuación de validación cruzada: 0.5784703564391904

# %% [markdown]
# #Realizamos la prediccion con nuestro modelo entrenado y optimizado
#
# La base de datos no incluye un y_test para realizar una comparacion con lo predicho, entonces no es posible calcular las metricas de precision para el modelo final

# %%
model_n1 = XGBClassifier(
    colsample_bytree=0.8,
    learning_rate=0.1,
    max_depth=5,
    n_estimators=300,
    subsample=0.8,
    use_label_encoder=False,
    eval_metric='logloss'
)

model_n1.fit(X_train_pca, y_train)

scaler = StandardScaler()
X_test_scaled = scaler.fit_transform(X_test)
pca = PCA(n_components=0.95)
X_test_pca = pca.fit_transform(X_test_scaled)

# Realizar predicciones sobre el conjunto de prueba
y_pred = model_n1.predict(X_test_pca)

# Si deseas ver algunas de las predicciones
print("Predicciones del conjunto de prueba:", y_pred[:10])  # Mostrar las primeras 10 predicciones
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:52:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Predicciones del conjunto de prueba: [3 2 1 0 1 2 1 3 0 0]

# %% [markdown]
# # Conclusiones

# %% [markdown]
# Se recomienda obtener una mayor cantidad de datos numericos el modelo se puede ajustar mejor, sin embargo puede ser una buena aproximacion para las personas que buscan cambiar o buscar hogar en los paises bajos para realizar un presupuesto inicial a su cambio de vida.
